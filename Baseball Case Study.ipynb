# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# As we can see 1 column is of float data type and all others are of integer data type.

# %%
#Check null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# We can observe that there are no null values in any of the columns.

# %%
#Visulaize null values
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# We can also visualize that there are no null values in the dataset.

# %%
#Check the counts of unique values of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# We can observe that all columns have continuous data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# We can observe that there are 1 float data type and 16 integer data type columns in the dataset.

# %%
#Statistical summary of numerical columns
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# We can observe the following from the above summary:

# %% [markdown]
# There are no null values in the dataset.

# %% [markdown]
# The columns "H" and "HR" are skewed to the right as the mean is higher than the median.

# %% [markdown]
# The columns "R" and "E" have outliers as the max is much higher than 75%.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Let's visualize the distribution of each variable

# %%
#Visualize the distribution of data for all the columns
plt.figure(figsize=(10,16),facecolor="white")
plotnumber=1
for col in df.columns:
    ax=plt.subplot(6,3,plotnumber)
    sns.distplot(df[col],color="magenta")
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We dan observe the following from the above grapths:

# %% [markdown]
# Data in all the columns are normally distributed.

# %% [markdown]
# The columns "R", "CG", "SHO", "SV" and "E" appear to be right skewed.

# %% [markdown]
# There is not much of skewness in the other columns.

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Let's analyse the relationship between the features and the label

# %%
#Analyse the correlation between the features and the label
plt.figure(figsize=(10,16),facecolor="white")
plotnumber=1
for col in df.columns[1:]:
    ax=plt.subplot(6,3,plotnumber)
    sns.scatterplot(x=col,y='W',data=df,color='violet')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can observe the following from the above graphs:

# %% [markdown]
# There is a positive correlation between the features "R", "2B", "HR", "BB", "SO", "SHO" and "SV" and the label "W".

# %% [markdown]
# There is no correlation between the features "AB", "H", "3B", "SB", "CG" and "E" and the label "W".

# %% [markdown]
# There is negative correlation between the features "RA", "ER" and "ERA" and the label "W".

# %% [markdown]
# Checking for Outliers

# %% [markdown]
# Outliers are checked for numerical columns. All the columns are numerical in this dataset. So, we will check outliers for all the columns.

# %%
plt.figure(figsize=(10,16),facecolor="white")
plotnumber=1
for col in df.columns:
    ax=plt.subplot(6,3,plotnumber)
    sns.boxplot(df[col],palette="plasma")
    plt.xlabel(col,fontsize=12)
    plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can find outliers in the features "R", "ERA", "SHO", "SV" and "E". We will remove these outliers using IQR method.

# %%
#Separate the features with outliers
out_features=df[['R','ERA','SHO','SV','E']]

#Calculate IQR
Q1=out_features.quantile(0.25)
Q3=out_features.quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

#Remove outliers
df1=df[((out_features>=lower_bound) & (out_features<=upper_bound)).all(axis=1)]

# %%
df1.shape
# Out:
# (20, 17)

# %%
print("Data loss percentage - ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage -  33.33333333333333

# %% [markdown]
# Data loss percentage is 33.33%. This is much above 10% and is not acceptable. Also the observations are all valid observations. So, we decide not to remove the outliers and keep them. Therefore, we will continue with the original dataframe "df".

# %% [markdown]
# Checking for Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We can observe that the columns "R", "H", "HR", "CG", "SHO", "SV" and "E" have skewness. We will remove skewness from these columns using Yeo-Johnson transformation method.

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
df["R"]=pt.fit_transform(df[["R"]])
df["H"]=pt.fit_transform(df[["H"]])
df["HR"]=pt.fit_transform(df[["HR"]])
df["CG"]=pt.fit_transform(df[["CG"]])
df["SHO"]=pt.fit_transform(df[["SHO"]])
df["SV"]=pt.fit_transform(df[["SV"]])
df["E"]=pt.fit_transform(df[["E"]])

# %%
#Check skewness again
df.skew()
# Out:
# W      0.047089
# R     -0.055006
# AB     0.183437
# H      0.000000
# 2B    -0.230650
# 3B     0.129502
# HR    -0.000065
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %% [markdown]
# Now, we have reduced the skewness from all the columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     float64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     float64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     float64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     float64
#  14  SHO     30 non-null     float64
#  15  SV      30 non-null     float64
#  16  E       30 non-null     float64
# dtypes: float64(8), int64(9)
# memory usage: 4.1 KB

# %%
#Statistical summary of numerical columns
df.describe()
# Out:
#                 W             R           AB             H          2B  \
# count   30.000000  3.000000e+01    30.000000  3.000000e+01   30.000000
# mean    80.966667  6.666247e-11  5516.266667  1.202742e-17  274.733333
# std     10.453455  1.017095e+00    70.467372  3.222585e-16   18.095405
# min     63.000000 -2.648512e+00  5385.000000 -4.996004e-16  236.000000
# 25%     74.000000 -6.119693e-01  5464.000000 -2.220446e-16  262.250000
# 50%     81.000000  1.356222e-01  5510.000000 -8.326673e-17  275.500000
# 75%     87.750000  6.363778e-01  5570.000000  3.053113e-16  288.750000
# max    100.000000  2.671903e+00  5649.000000  5.828671e-16  308.000000
#
#               3B            HR          BB          SO          SB  \
# count  30.000000  3.000000e+01   30.000000    30.00000   30.000000
# mean   31.300000  7.179442e-16  469.100000  1248.20000   83.500000
# std    10.452355  1.017095e+00   57.053725   103.75947   22.815225
# ...

# %% [markdown]
# We can observe that the skewness in all the columns have been reduced as we can see that the mean is almmost equal to the median in the columns.

# %%
#Check correlation between features and label
cor=df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.460294 -0.087947  0.018306  0.427797 -0.251118  0.319035
# R    0.460294  1.000000  0.365187  0.457600  0.572240  0.001872  0.696539
# AB  -0.087947  0.365187  1.000000  0.739733  0.453370  0.435422 -0.032412
# H    0.018306  0.457600  0.739733  1.000000  0.559257  0.468861 -0.095482
# 2B   0.427797  0.572240  0.453370  0.559257  1.000000  0.220490  0.080441
# 3B  -0.251118  0.001872  0.435422  0.468861  0.220490  1.000000 -0.385721
# HR   0.319035  0.696539 -0.032412 -0.095482  0.080441 -0.385721  1.000000
# BB   0.484342  0.378223 -0.136414 -0.120003  0.302700 -0.454949  0.422742
# SO   0.111850  0.017863 -0.106022 -0.409245 -0.150752 -0.141196  0.387598
# SB  -0.157234  0.078819  0.372618  0.422479  0.195027  0.457437 -0.134965
# RA  -0.812952 -0.074554  0.316010  0.223770 -0.218160  0.314125 -0.107588
# ER  -0.809435 -0.068647  0.309686  0.253766 -0.235531  0.340225 -0.089520
# ...

# %%
#Visualize the correlation between features and label
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),linewidths=0.1,fmt='.1g',linecolor='black',annot=True,cmap='plasma')
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# We can observe the following from the above graph:

# %% [markdown]
# The features "SB", "RA", "ER" and "ERA" are negatively correlated with label "W" and all the other features are postively correlated with the label.

# %% [markdown]
# The features "RA", "ER" and "ERA" have high negative correlation with the label "W".

# %% [markdown]
# The feature "SV" has high positive correlation with the label "W".

# %% [markdown]
# The features "RA" and "SV", "ER" and "SV", "ERA" and "SV", "RA" and "SHO", "ER" and "SHO", "ERA" and "SHO" have high negative correlation with each other.

# %% [markdown]
# The features "R" and "HR", "R" and "2B", "H" and "2B", "AB" and ""H" have high positive correlation with each other.

# %% [markdown]
# The features "RA" and "ERA", "ER" and "ERA", "RA" and "ER" have perfect positive correlation with each other.

# %%
#Correlation between features and label
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666202
# BB     0.484342
# R      0.460294
# SHO    0.458964
# 2B     0.427797
# HR     0.319035
# SO     0.111850
# CG     0.058044
# H      0.018306
# AB    -0.087947
# E     -0.091426
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %%
#Visualize the correlation between features and label
plt.figure(figsize=(18,6))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='orange')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Label',fontsize=15)
plt.title('Correlation between features and label',fontsize=20)
plt.show()

# %% [markdown]
# We can observe that the feature "H" has very low correlation with the label "W".

# %% [markdown]
# Separating features and label

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.728218  0.847731  1.538852  1.420173  1.041193 -0.764626 -1.534902
# 1   0.261212 -0.711094 -1.001568  0.127403  1.235809 -0.158581 -0.536592
# 2  -0.244821 -1.115233 -0.037960  1.588795 -0.223808 -0.689676  1.139144
# 3  -1.285129  0.241522 -0.300762 -0.828122 -0.418423 -0.879049 -1.160536
# 4   0.135622  1.280738  1.801654  0.801892  1.722347 -0.329850 -0.251360
# 5   2.671903 -0.104884  1.363650  1.869832 -1.391501  1.937860  1.798742
# 6   1.309688  0.732263 -0.037960 -0.153633 -1.196885  1.460099  1.513510
# 7   0.551199 -0.451289 -0.563564 -1.615025 -1.099578  1.583551 -0.910958
# 8  -0.770266 -0.451289 -0.300762  0.183611  0.068115  0.200058 -0.590073
# 9   1.088096  1.785913  1.538852  1.082929  0.165423  0.007404  0.158660
# 10  1.130709 -0.076017  0.400043  0.239818  0.068115  0.355503  0.604334
# 11  0.806086 -0.826562 -0.738766  0.183611 -0.515731  1.891937  0.301276
# ...

# %% [markdown]
# Now, all the features have been scaled to overcome the issue of biasness in the model.

# %% [markdown]
# Checking Variance Inflation Factor (VIF)

# %%
#Find Variance Inflation Factor of each feature
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#      VIF Values Features
# 0     10.704962        R
# 1     13.224892       AB
# 2      7.444499        H
# 3      3.675330       2B
# 4      3.288864       3B
# 5     11.318836       HR
# 6      3.491266       BB
# 7      2.671783       SO
# 8      1.959087       SB
# 9    211.333362       RA
# 10  1983.056519       ER
# 11  1403.538765      ERA
# 12     2.610421       CG
# 13     3.168709      SHO
# 14     4.917794       SV
# 15     1.995502        E

# %% [markdown]
# We can see that the features "R", "AB", "HR", "RA", "ER" and "ERA" have VIF values greater than 10 which indicates that there is multicollinearity problem with the features. We will remove the feature "ER" which has the highest VIF value first and then check the VIF values again.

# %%
#Copy x into a new dataframe and drop the column
x1=x.copy()
x1.drop("ER",axis=1,inplace=True)

# %%
#Check the VIF values again
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x1.values,i) for i in range(len(x1.columns))]
vif["Features"]=x1.columns
vif
# Out:
#     VIF Values Features
# 0     8.636554        R
# 1     5.357509       AB
# 2     7.377587        H
# 3     3.511992       2B
# 4     3.210276       3B
# 5     8.129296       HR
# 6     3.491265       BB
# 7     2.535088       SO
# 8     1.777125       SB
# 9   128.763735       RA
# 10  128.165711      ERA
# 11    2.421179       CG
# 12    2.985188      SHO
# 13    2.446026       SV
# 14    1.980599        E

# %% [markdown]
# Now, we can see that only the columns "RA" and "ERA" have VIF values greater than 10. So, we will remove "RA" which has the highest VIF value first and then check the VIF values again.

# %%
x1.drop("RA",axis=1,inplace=True)

# %%
#Check the VIF vlaues again
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x1.values,i) for i in range(len(x1.columns))]
vif["Features"]=x1.columns
vif
# Out:
#     VIF Values Features
# 0     8.590705        R
# 1     3.789771       AB
# 2     6.512411        H
# 3     3.357934       2B
# 4     3.037889       3B
# 5     7.293190       HR
# 6     3.112336       BB
# 7     2.218997       SO
# 8     1.760776       SB
# 9     4.662657      ERA
# 10    2.367012       CG
# 11    2.899187      SHO
# 12    2.144453       SV
# 13    1.853777        E

# %% [markdown]
# Now, we can see that none of the features have VIF values greater than 10. Hence the problem of multicollinearity has been solved and we can proceed further.

# %%
#Copy x1 into the original dataframe x
x=x1.copy()

# %% [markdown]
# # Model Building

# %% [markdown]
# Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import ExtraTreesRegressor
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    ETR=ExtraTreesRegressor()
    ETR.fit(x_train,y_train)
    pred=ETR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 Score is ",maxAccu,"on Random State ",maxRS)
# Out:
# Maximum R2 Score is  0.8496914619314033 on Random State  163

# %% [markdown]
# Creating train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=maxRS)

# %% [markdown]
# Importing the necessary modules

# %%
from sklearn.linear_model import LinearRegression,Lasso
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
#Extra Trees Regressor
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_ETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_ETR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_ETR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_ETR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score:  0.9174057893456581
# R2_score on training data:  1.0
# Mean Absolute Error:  1.903749999999997
# Mean Squared Error:  5.305387499999997
# Root Mean Squared Error:  2.3033426796723053

# %%
#Linear Regression
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_LR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score:  0.8174152825548086
# R2_score on training data:  0.9381019896188488
# Mean Absolute Error:  3.125697973120717
# Mean Squared Error:  11.72821520964347
# Root Mean Squared Error:  3.42464818771848

# %%
#Lasso
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_lasso))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score:  0.9355823622568756
# R2_score on training data:  0.8867785515738709
# Mean Absolute Error:  1.7430411956097647
# Mean Squared Error:  4.137826699406006
# Root Mean Squared Error:  2.0341648653454825

# %%
#XGB Regressor
XGB=XGBRegressor()
XGB.fit(x_train,y_train)
pred_XGB=XGB.predict(x_test)
pred_train=XGB.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_XGB))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_XGB))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_XGB))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_XGB)))
# Out:
# R2_score:  0.4616696287775234
# R2_score on training data:  0.9999999979639723
# Mean Absolute Error:  4.618133544921875
# Mean Squared Error:  34.579314938993775
# Root Mean Squared Error:  5.880417922137318

# %%
#Decision Tree Regressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_DTR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_DTR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_DTR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# R2_score:  -0.397226952079786
# R2_score on training data:  1.0
# Mean Absolute Error:  8.0
# Mean Squared Error:  89.75
# Root Mean Squared Error:  9.473647660748208

# %%
#Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_RFR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score:  0.8829117976161516
# R2_score on training data:  0.9121898033303639
# Mean Absolute Error:  2.1212500000000016
# Mean Squared Error:  7.521087500000011
# Root Mean Squared Error:  2.7424601182150328

# %%
#Gradient Boosting Regressor
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_GBR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score:  0.5172393701730351
# R2_score on training data:  0.9999997255125627
# Mean Absolute Error:  3.8243132377135325
# Mean Squared Error:  31.009827331541445
# Root Mean Squared Error:  5.568646813323812

# %%
#Bagging Regressor
BR=BaggingRegressor()
BR.fit(x_train,y_train)
pred_BR=BR.predict(x_test)
pred_train=BR.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_BR))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_BR))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_BR))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_BR)))
# Out:
# R2_score:  0.7373680369739724
# R2_score on training data:  0.9011221133420133
# Mean Absolute Error:  2.450000000000001
# Mean Squared Error:  16.869999999999997
# Root Mean Squared Error:  4.107310555582569

# %%
#KNeighbors Regressor
KNN=KNeighborsRegressor()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
pred_train=KNN.predict(x_train)
print("R2_score: ",r2_score(y_test,pred_KNN))
print("R2_score on training data: ",r2_score(y_train,pred_train))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred_KNN))
print("Mean Squared Error: ",mean_squared_error(y_test,pred_KNN))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# R2_score:  0.7253028460228653
# R2_score on training data:  0.6902994586445556
# Mean Absolute Error:  3.4250000000000007
# Mean Squared Error:  17.64500000000001
# Root Mean Squared Error:  4.200595195921646

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
#Cross Validation of Extra Trees Regressor model
score=cross_val_score(ETR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_ETR)-score.mean())*100)
# Out:
# [-0.10081696 -3.51890344  0.34323511  0.28176948  0.80459065]
# -0.43802503090920136
# Difference between R2 score and cross validation score is -  135.54308202548594

# %%
#Cross Validation of Linear Regression model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.54395703 -0.50323274  0.47411371  0.62962296  0.67067866]
# 0.3630279247032536
# Difference between R2 score and cross validation score is -  45.438735785155494

# %%
#Cross Validation of score for Lasso model
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.69146641 -0.06427359  0.67073198  0.72684313  0.91069695]
# 0.5870929761548063
# Difference between R2 score and cross validation score is -  34.848938610206936

# %%
#Cross Validation of XGB Regressor model
score=cross_val_score(XGB,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_XGB)-score.mean())*100)
# Out:
# [ 0.08734291 -6.21087141 -0.18035626  0.42696055  0.3920183 ]
# -1.0969811813973673
# Difference between R2 score and cross validation score is -  155.86508101748908

# %%
#Cross Validation of Decison Tree Regressor model
score=cross_val_score(DTR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_DTR)-score.mean())*100)
# Out:
# [-1.37122558 -9.8778626  -0.61652704  0.48006279 -0.20710059]
# -2.318530601474216
# Difference between R2 score and cross validation score is -  192.130364939443

# %%
#Cross Validation of Random Forest Regressor model
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.2265968  -5.69280305  0.14154726  0.30892509  0.59076467]
# -0.8849938463014784
# Difference between R2 score and cross validation score is -  176.79056439176298

# %%
#Cross Validation of Gradient Boosting Regressor model
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-7.03263259e-03 -7.28687073e+00  1.99906191e-01  6.55170337e-01
#   5.25223354e-01]
# -1.1827206962537138
# Difference between R2 score and cross validation score is -  169.9960066426749

# %%
#Cross Validation of Bagging Regressor model
score=cross_val_score(BR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_BR)-score.mean())*100)
# Out:
# [ 0.01535524 -4.86706107  0.34933359  0.41154788  0.43898225]
# -0.7303684224998224
# Difference between R2 score and cross validation score is -  146.77364594737946

# %%
#Cross Validation of KNeighbors Regressor model
score=cross_val_score(KNN,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ",(r2_score(y_test,pred_KNN)-score.mean())*100)
# Out:
# [ 0.11992895 -2.03526718  0.22635187  0.36296389  0.44906509]
# -0.17539147511341185
# Difference between R2 score and cross validation score is -  90.06943211362773

# %% [markdown]
# Lasso model is our best performing model as the difference between R2 score and cross validation score for this model is the least among all the good performing models.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha': [1e-4, 1e-3, 1e-2, 0.1, 1, 10, 100, 1000, 10000],
       'max_iter': [500, 1000, 2000, 5000, 10000],
       'tol': [1e-6, 1e-4, 1e-3, 1e-2, 0.1],
       'fit_intercept': [True, False],
       'selection': ['cyclic', 'random']
      }
GCV=GridSearchCV(Lasso(),param,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000,
#                                    10000],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 2000, 5000, 10000],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [1e-06, 0.0001, 0.001, 0.01, 0.1]})

# %%
#Best parameters for the final model
GCV.best_params_
# Out:
# {'alpha': 1,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'selection': 'cyclic',
#  'tol': 0.1}

# %% [markdown]
# # Building the final model

# %%
final_model=Lasso(alpha=1,
                  fit_intercept=True,
                  max_iter=500,
                  selection='cyclic',
                  tol=0.1
                 )
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
print("R2_score: ",r2_score(y_test,pred))
print("Mean Absolute Error: ",mean_absolute_error(y_test,pred))
print("Mean Squared Error: ",mean_squared_error(y_test,pred))
print("Root Mean Squared Error: ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score:  0.947656243078234
# Mean Absolute Error:  1.498399621755052
# Mean Squared Error:  3.3622685110215635
# Root Mean Squared Error:  1.8336489606851043

# %%
#Save the model
import pickle
filename='Baseball_Case_Study.pkl'
pickle.dump(final_model,open(filename,'wb'))

# %%
#Load the saved model and compute the score
loaded_model=pickle.load(open('Baseball_Case_Study.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print("Loaded model's score: ",result*100)
# Out:
# Loaded model's score:  94.7656243078234

# %%
#Prediction using the loaded model
df1=pd.DataFrame()
df1['Original']=y_test
df1['Predicted']=loaded_model.predict(x_test)
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#    Original  Predicted
# 0        90  90.549340
# 1        76  77.891032
# 2        74  76.610449
# 3        86  87.604497
# 4        92  88.608913
# 5        78  79.411179
# 6        68  67.748863
# 7        87  86.721524
